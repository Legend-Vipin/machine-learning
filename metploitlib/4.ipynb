# %% [markdown]
# # Learn Histogram Chart in matplotlib

# %%
import matplotlib as plt
import numpy as np
import random
X=np.random.randint(10,60,50)
print(X)
# Out:
# [12 56 45 18 50 18 58 54 17 52 10 39 27 40 28 19 30 24 48 51 59 47 58 27
#  32 26 47 22 22 20 10 15 52 20 47 25 31 40 52 58 32 15 22 21 40 12 45 30
#  10 59]

# %%
import matplotlib.pyplot as plt 
no = [32, 55, 32, 37, 43, 32, 43, 21, 38, 17, 33,
13, 13, 42, 53, 14, 55, 50, 36, 14, 22, 19, 43, 59, 23, 33, 14, 57, 34, 41, 42, 18, 29,
19, 13, 49, 40, 27, 57, 45, 14, 44, 22, 52, 53, 24, 52, 22, 19, 55]
l=[10,20,30,40,50,60]
# plt.hist(no,color="b",edgecolor="r",cumulative=-1,bottom=10,align="mid",histtype="step",orientation="horizontal")
plt.hist(no,color="b",bins=l,edgecolor="r",label="python")
# plt.hist(no,"auto",(0,100),edgecolor="r")
plt.title("wscube tech")
plt.xlabel("python")
plt.ylabel("No.")

plt.axvline(45,color="g",label="line")
plt.grid()
plt.legend()
plt.show()
